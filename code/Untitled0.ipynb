# %%
import thinkdsp

wave = thinkdsp.CosSignal(freq=60)
wave = wave.make_wave().make_spectrum()
wave.plot()

# %%
wave.band_stop(59.99, 60.01)
wave.plot()

# %%
noise = thinkdsp.UncorrelatedGaussianNoise().make_wave().make_spectrum()
noise.plot()

# %%
noise.pink_filter()
noise.plot()

# %%
noise.pink_filter()
noise.plot()

# %%
noise.make_wave().plot()

# %%
wave = thinkdsp.ExpoChirp(start=220, end=880).make_wave().make_spectrogram(seg_length=512)
wave.plot(high=64)
